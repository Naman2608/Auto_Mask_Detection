# %%
import numpy as np
import cv2
# pip install opencv-python
# pip install scik
# it-learn
# pip instal numpy

# %%
with_mask=np.load("with_mask.npy")
without_mask=np.load("without_mask.npy")

# %%
with_mask = with_mask.reshape(200,50*50*3)
without_mask = without_mask.reshape(200,50*50*3)

# %%
X= np.r_[with_mask,without_mask]

# %%
lables = np.zeros(X.shape[0])

# %%
lables[200:] = 1.0

# %%
names = {0: 'Mask', 1:'No mask'}

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %%
x_train,x_test,y_train,y_test = train_test_split(X,lables,test_size=0.25)

# %%
pca = PCA(n_components=3)
x_train = pca .fit_transform(x_train)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,lables, test_size=0.25)

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
x_test = pca.transform(x_test)
y_pred = svm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-86e1b10703d2> in <module>
# ----> 1 accuracy_score(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
haar_data = cv2.CascadeClassifier('data.xml')
live_img=cv2.VideoCapture(0)
data=[]
font = cv2.FONT_HERSHEY_COMPLEX
while True:
    flag, img = live_img.read()
    if flag:
        faces = haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(22,255,255),4)
            faces=img[y:y+h,x:x+w, : ]
            faces= cv2.resize(faces,(50,50))
            faces = faces.reshape(1,-1)
            #faces= pca.transform(faces)
            pred = svm.predict(faces)
            n = names[int(pred)]
            cv2.putText(img, n, (x,y),font,1,(0,0,255),2)
            print(n)
        cv2.imshow('new tab name',img)
        # 27 - Ascii of Escape
        if cv2.waitKey(2) == 27 or len(data)>=50:
            break
live_img.release()
cv2.destroyAllWindows()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/naman/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# No mask
# Mask
# No mask
# No mask
# No mask
# Mask
# No mask
# No mask
# Mask
# No mask
# Mask
# Mask
# No mask
# No mask
# Mask
# No mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# Mask
# No mask
# No mask
# Mask
# No mask
# Mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# Mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
# No mask
